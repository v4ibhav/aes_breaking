# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("traces.csv",header=None)
print(df.loc[0,0:10])
# Out:
# 0     1620
# 1     4315
# 2     5813
# 3     7012
# 4     7611
# 5     7910
# 6     7611
# 7     6412
# 8     5514
# 9     5214
# 10    4914
# Name: 0, dtype: int64

# %%
for i in range(0,5):
    plt.plot(df.loc[i,0:200],'o-')
# plt.plot(df.loc[1000,0:200],'o-')

plt.xlabel("Column Number")
plt.ylabel("Value")
plt.title("Values in Each Column")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("test.csv",header=None)
print(df.loc[0,0:10])
# Out:
# 0    -0.003565
# 1     0.003570
# 2    -0.000238
# 3     0.006754
# 4     0.008052
# 5    -0.005045
# 6    -0.001449
# 7     0.005224
# 8     0.001484
# 9    -0.004026
# 10    0.000234
# Name: 0, dtype: float64

# %%
for i in range(0,256):
    if(i == 0):
        plt.plot(df.loc[i,0:400],'-', label= '0x00')
    if(i == 255):
        plt.plot(df.loc[i,0:400],'-', label = '0xff')
# plt.plot(df.loc[1000,0:200],'o-')

plt.xlabel("timestamps")
plt.ylabel("Pearson Coefficient")
plt.title("for Keys 0x00 and 0xff")
plt.legend()
plt.show()

# %%
import csv

# Initialize a variable to store the minimum value
min_value = None
max_value = None

# Open the CSV file for reading
with open('test.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)

    # Iterate through the rows and columns
    for row_value,row in enumerate(reader):
        for col_value,cell in enumerate(row):
            try:
                # Attempt to convert the cell value to a floating-point number
                value = float(cell)

                # Check if the value is smaller than the current min_value
                if min_value is None or value < min_value:
                    min_value = value
                    key_row_min = row_value
                    time_stamp_min = col_value
                elif max_value is None or value > max_value:
                    max_value = value
                    key_row_max = row_value
                    time_stamp_max = col_value
                    

            except ValueError:
                # Ignore non-numeric values in the CSV
                pass

# Display the smallest value
if min_value is not None:
    print("The smallest pearson coefficient is:", min_value, "the key is ", key_row_min, " the time stamp is ", time_stamp_min)
if max_value is not None:
    print("The largest pearson coefficient is:", max_value, "the key is ", key_row_max, " the time stamp is ", time_stamp_max)

else:
    print("No numeric values found in the CSV file.")
# Out:
# The smallest pearson coefficient is: -0.0470961 the key is  61  the time stamp is  129
# The largest pearson coefficient is: 0.0392852 the key is  9  the time stamp is  304

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("test_with_xor_operation.csv",header=None)
print(df.loc[0,0:10])
# Out:
# 0     0.008582
# 1    -0.005962
# 2    -0.002627
# 3     0.003582
# 4    -0.008065
# 5    -0.006591
# 6    -0.020341
# 7    -0.017923
# 8    -0.019163
# 9    -0.021351
# 10   -0.000849
# Name: 0, dtype: float64

# %%
for i in range(0,256):
    if(i == 0):
        plt.plot(df.loc[i,0:400],'-', label= '0x00')
    if(i == 255):
        plt.plot(df.loc[i,0:400],'-', label = '0xff')
# plt.plot(df.loc[1000,0:200],'o-')

plt.xlabel("timestamps")
plt.ylabel("Pearson Coefficient")
plt.title("for Keys 0x00 and 0xff")
plt.legend()
plt.show()

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

# Initialize a variable to store the minimum value
min_value = None
max_value = None

# Open the CSV file for reading
with open('test_with_xor_operation.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)

    # Iterate through the rows and columns
    for row_value,row in enumerate(reader):
        for col_value,cell in enumerate(row):
            try:
                # Attempt to convert the cell value to a floating-point number
                value = float(cell)

                # Check if the value is smaller than the current min_value
                if min_value is None or value < min_value:
                    min_value = value
                    key_row_min = row_value
                    time_stamp_min = col_value
                elif max_value is None or value > max_value:
                    max_value = value
                    key_row_max = row_value
                    time_stamp_max = col_value
                    

            except ValueError:
                # Ignore non-numeric values in the CSV
                pass

# Display the smallest value
if min_value is not None:
    print("The smallest pearson coefficient is:", min_value, "the key is ", key_row_min, " the time stamp is ", time_stamp_min)
if max_value is not None:
    print("The largest pearson coefficient is:", max_value, "the key is ", key_row_max, " the time stamp is ", time_stamp_max)

else:
    print("No numeric values found in the CSV file.")
# Out:
# The smallest pearson coefficient is: -0.117301 the key is  0  the time stamp is  43
# The largest pearson coefficient is: 0.117301 the key is  255  the time stamp is  43

# %%
import csv

def process_csv_file(filename):
    # Initialize variables for the minimum and maximum values
    min_value = None
    max_value = None
    key_row_min = None
    key_row_max = None
    time_stamp_min = None
    time_stamp_max = None

    # Open the CSV file for reading
    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile)

        # Iterate through the rows and columns
        for row_value, row in enumerate(reader):
            for col_value, cell in enumerate(row):
                try:
                    # Attempt to convert the cell value to a floating-point number
                    value = float(cell)

                    # Check if the value is smaller than the current min_value
                    if min_value is None or value < min_value:
                        min_value = value
                        key_row_min = row_value
                        time_stamp_min = col_value
                    elif max_value is None or value > max_value:
                        max_value = value
                        key_row_max = row_value
                        time_stamp_max = col_value

                except ValueError:
                    # Ignore non-numeric values in the CSV
                    pass

    # Display the smallest and largest values for the current file
    if min_value is not None:
        print(f"For file {filename}:")
        print("  The smallest pearson coefficient is:", min_value, "the key is ", key_row_min, " the time stamp is ", time_stamp_min)
    if max_value is not None:
        print("  The largest pearson coefficient is:", max_value, "the key is ", key_row_max, " the time stamp is ", time_stamp_max)
    else:
        print(f"For file {filename}: No numeric values found in the CSV file.")

# List of filenames to process
filenames = ["correlation_256x400_for_1st_byte.csv", "correlation_256x400_for_2nd_byte.csv",
        "correlation_256x400_for_3rd_byte.csv",
        "correlation_256x400_for_4th_byte.csv",
        "correlation_256x400_for_5th_byte.csv",
        "correlation_256x400_for_6th_byte.csv",
        "correlation_256x400_for_7th_byte.csv",
        "correlation_256x400_for_8th_byte.csv",
        "correlation_256x400_for_9th_byte.csv",
        "correlation_256x400_for_10th_byte.csv",
        "correlation_256x400_for_11th_byte.csv",
        "correlation_256x400_for_12th_byte.csv",
        "correlation_256x400_for_13th_byte.csv",
        "correlation_256x400_for_14th_byte.csv",
        "correlation_256x400_for_15th_byte.csv",
        "correlation_256x400_for_16th_byte.csv"]

# Process each CSV file
for filename in filenames:
    process_csv_file(filename)
# Out:
# For file correlation_256x400_for_1st_byte.csv:
#   The smallest pearson coefficient is: -0.117301 the key is  0  the time stamp is  43
#   The largest pearson coefficient is: 0.117301 the key is  255  the time stamp is  43
# For file correlation_256x400_for_2nd_byte.csv:
#   The smallest pearson coefficient is: -0.114948 the key is  1  the time stamp is  43
#   The largest pearson coefficient is: 0.114948 the key is  254  the time stamp is  43
# For file correlation_256x400_for_3rd_byte.csv:
#   The smallest pearson coefficient is: -0.160848 the key is  2  the time stamp is  43
#   The largest pearson coefficient is: 0.160848 the key is  253  the time stamp is  43
# For file correlation_256x400_for_4th_byte.csv:
#   The smallest pearson coefficient is: -0.145542 the key is  3  the time stamp is  43
#   The largest pearson coefficient is: 0.145542 the key is  252  the time stamp is  43
# For file correlation_256x400_for_5th_byte.csv:
#   The smallest pearson coefficient is: -0.132193 the key is  4  the time stamp is  43
#   The largest pearson coefficient is: 0.132193 the key is  251  the time stamp is  43
# For file correlation_256x400_for_6th_byte.csv:
#   The smallest pearson coefficient is: -0.118003 the key is  133  the time stamp is  43
#   The largest pearson coefficient is: 0.118003 the key is  122  the time stamp is  43
# For file correlation_256x400_for_7th_byte.csv:
#   The smallest pearson coefficient is: -0.131147 the key is  6  the time stamp is  43
#   The largest pearson coefficient is: 0.131147 the key is  249  the time stamp is  43
# For file correlation_256x400_for_8th_byte.csv:
#   The smallest pearson coefficient is: -0.11538 the key is  248  the time stamp is  37
#   The largest pearson coefficient is: 0.11538 the key is  7  the time stamp is  37
# For file correlation_256x400_for_9th_byte.csv:
#   The smallest pearson coefficient is: -0.112411 the key is  8  the time stamp is  43
#   The largest pearson coefficient is: 0.112411 the key is  247  the time stamp is  43
# For file correlation_256x400_for_10th_byte.csv:
#   The smallest pearson coefficient is: -0.112571 the key is  246  the time stamp is  38
#   The largest pearson coefficient is: 0.112571 the key is  9  the time stamp is  38
# For file correlation_256x400_for_11th_byte.csv:
#   The smallest pearson coefficient is: -0.120425 the key is  10  the time stamp is  43
#   The largest pearson coefficient is: 0.120425 the key is  245  the time stamp is  43
# For file correlation_256x400_for_12th_byte.csv:
#   The smallest pearson coefficient is: -0.123238 the key is  11  the time stamp is  43
#   The largest pearson coefficient is: 0.123238 the key is  244  the time stamp is  43
# For file correlation_256x400_for_13th_byte.csv:
#   The smallest pearson coefficient is: -0.0844953 the key is  12  the time stamp is  43
#   The largest pearson coefficient is: 0.0844953 the key is  243  the time stamp is  43
# For file correlation_256x400_for_14th_byte.csv:
#   The smallest pearson coefficient is: -0.123171 the key is  178  the time stamp is  37
#   The largest pearson coefficient is: 0.123171 the key is  77  the time stamp is  37
# For file correlation_256x400_for_15th_byte.csv:
#   The smallest pearson coefficient is: -0.125166 the key is  14  the time stamp is  43
#   The largest pearson coefficient is: 0.125166 the key is  241  the time stamp is  43
# For file correlation_256x400_for_16th_byte.csv:
#   The smallest pearson coefficient is: -0.116368 the key is  15  the time stamp is  43
#   The largest pearson coefficient is: 0.116368 the key is  240  the time stamp is  43

# %%
import csv

def process_csv_file(filename, output_file):
    # Initialize variables for the minimum and maximum values
    min_values = [float('inf')] * 2  # List to store the two smallest values, initialized with positive infinity
    max_values = [float('-inf')] * 2  # List to store the two largest values, initialized with negative infinity
    key_row_min = [None] * 2
    key_row_max = [None] * 2
    time_stamp_min = [None] * 2
    time_stamp_max = [None] * 2

    # Open the CSV file for reading
    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile)

        # Iterate through the rows and columns
        for row_value, row in enumerate(reader):
            for col_value, cell in enumerate(row):
                try:
                    # Attempt to convert the cell value to a floating-point number
                    value = float(cell)

                    # Update lists for the two smallest values
                    if value < min_values[0]:
                        min_values[1] = min_values[0]
                        key_row_min[1] = key_row_min[0]
                        time_stamp_min[1] = time_stamp_min[0]

                        min_values[0] = value
                        key_row_min[0] = row_value
                        time_stamp_min[0] = col_value
                    elif value < min_values[1]:
                        min_values[1] = value
                        key_row_min[1] = row_value
                        time_stamp_min[1] = col_value

                    # Update lists for the two largest values
                    if value > max_values[0]:
                        max_values[1] = max_values[0]
                        key_row_max[1] = key_row_max[0]
                        time_stamp_max[1] = time_stamp_max[0]

                        max_values[0] = value
                        key_row_max[0] = row_value
                        time_stamp_max[0] = col_value
                    elif value > max_values[1]:
                        max_values[1] = value
                        key_row_max[1] = row_value
                        time_stamp_max[1] = col_value

                except ValueError:
                    # Ignore non-numeric values in the CSV
                    pass

    # Display the results and write to the output file
    with open(output_file, 'a') as outputfile:
        outputfile.write(f"For file {filename}:\n")
        for i in range(2):
            if(i == 0):
                outputfile.write(f"  {i + 1}. The smallest pearson coefficient is: {min_values[i]}, the key is 0x{key_row_min[i]:x}, the time stamp is {time_stamp_min[i]}\n")
                outputfile.write(f"  {i + 1}. The largest pearson coefficient is: {max_values[i]}, the key is 0x{key_row_max[i]:x}, the time stamp is {time_stamp_max[i]}\n")

            if(i == 1):
                outputfile.write(f"  {i + 1}. The previous smallest pearson coefficient is: {min_values[i]}, the key is 0x{key_row_min[i]:x}, the time stamp is {time_stamp_min[i]}\n")
                outputfile.write(f"  {i + 1}. The previous largest pearson coefficient is: {max_values[i]}, the key is 0x{key_row_max[i]:x}, the time stamp is {time_stamp_max[i]}\n")

# List of filenames to process
filenames = ["correlation_256x400_for_1st_byte.csv", "correlation_256x400_for_2nd_byte.csv",
             "correlation_256x400_for_3rd_byte.csv",
        "correlation_256x400_for_4th_byte.csv",
        "correlation_256x400_for_5th_byte.csv",
        "correlation_256x400_for_6th_byte.csv",
        "correlation_256x400_for_7th_byte.csv",
        "correlation_256x400_for_8th_byte.csv",
        "correlation_256x400_for_9th_byte.csv",
        "correlation_256x400_for_10th_byte.csv",
        "correlation_256x400_for_11th_byte.csv",
        "correlation_256x400_for_12th_byte.csv",
        "correlation_256x400_for_13th_byte.csv",
        "correlation_256x400_for_14th_byte.csv",
        "correlation_256x400_for_15th_byte.csv",
        "correlation_256x400_for_16th_byte.csv"
        
            ]
output_file = "print_key_set_and_timestamps.txt"

# Process each CSV file and append the results to the output file
for filename in filenames:
    process_csv_file(filename, output_file)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv("the_evolution_of_first_byte_with_all_the_key.csv", header=None)

# Extract the row of Pearson coefficients (adjust the row number as needed)
coefficients = df.values[0]
print(coefficients)

# Create a list representing the number of measurements (10000 in this case)
measurements = list(range(1, 10000))

# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(df.loc[0,0:10000])
# plt.xlabel('Pearson Coefficient')
# plt.ylabel('Number of Measurements')
plt.title('Pearson Coefficients vs. Number of Measurements')
# plt.gca().invert_yaxis()  # Invert y-axis to have higher measurements at the top
plt.show()
# Out:
# [ 1.        0.741738  0.549228 ... -0.117224 -0.117301       nan]

# %%
import numpy as np
import pandas as pd


#this part of code will give the trace measurements

def find_max_value_timestamp_for_evolution(filename_evolution, output_file, byte_to_check):
    # Load the CSV file into a DataFrame
    df = pd.read_csv(filename_evolution, header=None)

    # Extract the first row as a 1D NumPy array
    first_row_array = np.array(df.iloc[byte_to_check])
    first_row_array = first_row_array[1000:]

    # Print the first row as a NumPy array
    max_value = 0
    index_v = 0
    for row_value, r in enumerate(first_row_array):
        if abs(r) > abs(max_value):
            max_value = r
            index_v = row_value

    with open(output_file, 'a') as output_file_obj:
        output_file_obj.write(f"The index value for the file {filename_evolution} is {index_v + 1000}\n")
        output_file_obj.write(f"the key is 0x{byte_to_check:x}\n")
        output_file_obj.write(f"Max value: {max_value}\n")

# List of filenames to process
filenames = ["evolution_of_the_1st_byte.csv",
             "evolution_of_the_2nd_byte.csv",
             "evolution_of_the_3rd_byte.csv",
             "evolution_of_the_4th_byte.csv",
            "evolution_of_the_5th_byte.csv",
            "evolution_of_the_6th_byte.csv",
            "evolution_of_the_7th_byte.csv",
            "evolution_of_the_8th_byte.csv",
            "evolution_of_the_9th_byte.csv",
            "evolution_of_the_10th_byte.csv",
            "evolution_of_the_11th_byte.csv",
            "evolution_of_the_12th_byte.csv",
            "evolution_of_the_13th_byte.csv",
            "evolution_of_the_14th_byte.csv",
            "evolution_of_the_15th_byte.csv",
            "evolution_of_the_16th_byte.csv"
            ]
output_file = "trace_value_from_evolution.txt"

with open(output_file, 'w') as clear_file:
    clear_file.write("")
# Process each CSV file and append the results to the output file
byte_to_check = 0
for filename in filenames:
    # Clear the output file by opening it in 'w' (write) mode
    find_max_value_timestamp_for_evolution(filename, output_file, byte_to_check)
    byte_to_check+=1
